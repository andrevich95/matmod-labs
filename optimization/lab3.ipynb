# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#define propertiest of the start ellips
x0 = (0,0)
Q = np.random.rand(3,3)

# %%
#draw projection to the start ellips
plt.plot(Q)
plt.show()

# %%
array = np.random.rand(5,5)
# Out:
# array([[0.93489339, 0.16152846, 0.90812594, 0.52791931, 0.50300806],
#        [0.11699335, 0.14550456, 0.17067423, 0.59506482, 0.18154263],
#        [0.01515078, 0.72404849, 0.39384047, 0.01154676, 0.6055068 ],
#        [0.99631332, 0.95526059, 0.49183183, 0.40656475, 0.88125308],
#        [0.11579261, 0.87514728, 0.92956044, 0.6747204 , 0.62030063]])
